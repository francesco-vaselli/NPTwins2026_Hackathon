# %% [markdown]
# <a href="https://colab.research.google.com/github/francesco-vaselli/NPTwins2026_Hackathon/blob/main/03_sampling_and_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # 🟪 MAGI System — CASPER-3
#
# **Submission id:** `magi-casper__pattern-blue`
#
# > *NERV / E-Project, Tokyo-3 Geofront. As woman.*
#
# Linear path with cosine LR decay, **400 epochs**, Heun at only 50 inner steps (NFE=100). Intuition over compute.
# Hypothesis: a longer, gentler training run beats a fancier path under the C2ST.
#
# (This is a test submission generated to exercise the leaderboard CI. It is not a real run.)

# %%
scorecard = {
    'ws_per_feature': [0.0380, 5.6120, 0.3170],
    'ws_sum':         5.9670,
    'c2st':           0.1150,
    'auc_delta_btag': 0.0310,
}
print('MAGI Sub-System: CASPER-3')
print('Pattern: Blue. Lance of Longinus on standby.')
for k, v in scorecard.items():
    print(f'  {k:18s}: {v}')
# Out:
# MAGI Sub-System: CASPER-3
# Pattern: Blue. Lance of Longinus on standby.
# ──────────────────────────────────────────────────────────
# Scorecard — CASPER-3 (linear + Heun 50, cosine LR, 400 ep)
# ──────────────────────────────────────────────────────────
#   WS [btag             ]:  0.0380   Δ=+0.0060
#   WS [pt [GeV]         ]:  5.6120   Δ=-0.3270
#   WS [N_const          ]:  0.3170   Δ=+0.0010
#   ws_sum                :  5.9670   Δ=-0.3200
#   c2st                  :  0.1150   Δ=+0.0150
#   auc_delta_btag        :  0.0310   Δ=+0.0090
#
# Decision: REJECT (1/3 in favour, MELCHIOR & BALTHASAR overrule).
# Override available: human pilot.

# %% [markdown]
# _Approval: Marduk Institute. Signed: Cmdr. G. Ikari._
