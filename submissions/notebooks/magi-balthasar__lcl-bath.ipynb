# %% [markdown]
# <a href="https://colab.research.google.com/github/francesco-vaselli/NPTwins2026_Hackathon/blob/main/03_sampling_and_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # 🟧 MAGI System — BALTHASAR-2
#
# **Submission id:** `magi-balthasar__lcl-bath`
#
# > *NERV / E-Project, Tokyo-3 Geofront. As mother.*
#
# Warm-started from `model_nb2.pt`, fine-tuned with the trigonometric path; Heun 100, baseline architecture, 80 additional epochs.
# Refuses to overfit her child.
#
# (This is a test submission generated to exercise the leaderboard CI. It is not a real run.)

# %%
scorecard = {
    'ws_per_feature': [0.0310, 5.0120, 0.2810],
    'ws_sum':         5.3240,
    'c2st':           0.0920,
    'auc_delta_btag': 0.0220,
}
print('MAGI Sub-System: BALTHASAR-2')
print('L.C.L. injection complete. AT Field nominal.')
for k, v in scorecard.items():
    print(f'  {k:18s}: {v}')
# Out:
# MAGI Sub-System: BALTHASAR-2
# L.C.L. injection complete. AT Field nominal.
# ──────────────────────────────────────────────────────────
# Scorecard — BALTHASAR-2 (trig + Heun 100, NB2 warm-start, 80 ep)
# ──────────────────────────────────────────────────────────
#   WS [btag             ]:  0.0310   Δ=-0.0010
#   WS [pt [GeV]         ]:  5.0120   Δ=-0.9270
#   WS [N_const          ]:  0.2810   Δ=-0.0350
#   ws_sum                :  5.3240   Δ=-0.9630
#   c2st                  :  0.0920   Δ=-0.0080
#   auc_delta_btag        :  0.0220   Δ=+0.0000
#
# Decision: ADOPT (with reservations).

# %% [markdown]
# _Approval: Marduk Institute. Signed: Misato._
